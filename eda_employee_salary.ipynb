# %%
import pandas as pd
df = pd.read_csv("employee_salary.csv")


df.to_csv("employee_salary.csv", index=False)
df = pd.read_csv("employee_salary.csv")
print("First 5 Records")
print(df.head())
print("\nLast 5 Records")
print(df.tail())
print("\nDataset Shape")
print(df.shape)
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])


print("Column Names")
print(df.columns)
print("\nData Types")
print(df.dtypes)
print("\nDataset Information")
df.info()
print("\nDescriptive Statistics")
print(df.describe())


df.loc[2, "Salary"] = None
df.loc[5, "Age"] = None
print("Missing Values")
print(df.isnull().sum())
print("\nPercentage of Missing Values")
print((df.isnull().sum() / len(df)) * 100)
print("\nColumn with Highest Missing Values")
print(df.isnull().sum().idxmax())
print("\nDataset Size Before Cleaning:", df.shape)
df = df.dropna()
print("Dataset Size After Cleaning:", df.shape)
# Out:
# First 5 Records
#    EmployeeID    Name Department  Age  Experience   Salary  Gender       City
# 0         101    John         HR   29           4  45000.0    Male  Bengaluru
# 1         102   Smith         IT   34           8  85000.0    Male     Mumbai
# 2         103    Emma    Finance   41          15  95000.0  Female      Delhi
# 3         104  Olivia         IT   26           2  52000.0  Female  Bengaluru
# 4         105    Liam  Marketing   38          12      NaN    Male       Pune
#
# Last 5 Records
#     EmployeeID     Name Department  Age  Experience   Salary  Gender  \
# 26         127   Elijah         HR   39          14  79000.0    Male
# 27         128  Matthew    Finance   40          16  91000.0    Male
# 28         129    Sofia         IT   26           3      NaN  Female
# 29         130    David  Marketing   33           9  63000.0    Male
# 30         102    Smith         IT   34           8  85000.0    Male
#
#          City
# 26      Delhi
# 27     Mumbai
# 28  Bengaluru
# 29       Pune
# 30     Mumbai
#
# Dataset Shape
# (31, 8)
# Number of Rows: 31
# Number of Columns: 8
# Column Names
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Experience', 'Salary',
#        'Gender', 'City'],
#       dtype='str')
#
# Data Types
# EmployeeID      int64
# Name              str
# Department        str
# Age             int64
# Experience      int64
# Salary        float64
# Gender            str
# City              str
# dtype: object
#
# Dataset Information
# <class 'pandas.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  31 non-null     int64
#  1   Name        31 non-null     str
#  2   Department  31 non-null     str
#  3   Age         31 non-null     int64
#  4   Experience  31 non-null     int64
#  5   Salary      24 non-null     float64
#  6   Gender      31 non-null     str
#  7   City        31 non-null     str
# dtypes: float64(1), int64(3), str(4)
# memory usage: 2.1 KB
#
# Descriptive Statistics
#        EmployeeID        Age  Experience         Salary
# count   31.000000  31.000000   31.000000      24.000000
# mean   115.064516  35.064516   10.451613   75958.333333
# std      8.988643   7.117750    6.576923   17838.598031
# min    101.000000  24.000000    1.000000   42000.000000
# 25%    107.500000  29.000000    5.000000   63750.000000
# 50%    115.000000  34.000000    9.000000   76500.000000
# 75%    122.500000  39.500000   14.500000   88750.000000
# max    130.000000  50.000000   25.000000  105000.000000
# Missing Values
# EmployeeID    0
# Name          0
# Department    0
# Age           1
# Experience    0
# Salary        8
# Gender        0
# City          0
# dtype: int64
#
# Percentage of Missing Values
# EmployeeID     0.000000
# Name           0.000000
# Department     0.000000
# Age            3.225806
# Experience     0.000000
# Salary        25.806452
# Gender         0.000000
# City           0.000000
# dtype: float64
#
# Column with Highest Missing Values
# Salary
#
# Dataset Size Before Cleaning: (31, 8)
# Dataset Size After Cleaning: (22, 8)
